# %%
import requests

nom_entreprise = "SDLV"
url = f"https://api.insee.fr/entreprises/sirene/V3/unites_legales?q=denominationUniteLegale:{nom_entreprise}"

headers = {
    'accept': 'application/json',
    'X-INSEE-Api-Key-Integration': '29f35d23-2973-4bc3-b35d-232973dbc3f2'


}

response = requests.get(url, headers=headers)
data = response.json()

for entreprise in data['unitesLegales']:
    print(entreprise['siren'], entreprise['denominationUniteLegale'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       4 url = f"https://api.insee.fr/entreprises/sirene/V3/unites_legales?q=denominationUniteLegale:{nom_entreprise}"
#       6 headers = {
#       7     "Authorization": "Bearer <TON_TOKEN_API>"
#       8 }
# ---> 10 response = requests.get(url, headers=headers)
#      11 data = response.json()
#      13 for entreprise in data['unitesLegales']:
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...
